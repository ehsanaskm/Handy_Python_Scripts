# %%
import matplotlib.pyplot as plt

labels = ['$CO_2$', '$H_2O$', '$N_2$', '$O_2$']
sizes = [8.41, 17.41, 71.69, 2.47]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(sizes, labels=labels, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

labels = ['$CO_2$', '$H_2O$', '$N_2$', '$O_2$']
sizes = [8.34, 16.02, 72.59, 2.8]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(sizes, labels=labels, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()



labels = ['$CO_2$', '$H_2O$', '$N_2$', '$O_2$']
sizes = [8.41, 17.41, 71.69, 2.47]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,colors=colors, autopct='%.1f%%')
ax.set_aspect('equal')
plt.savefig('Suncor.png', format='png', dpi=1000)
plt.show()



labels = ['$CO_2$', '$H_2O$', '$N_2$', '$O_2$']
sizes = [8.34, 16.02, 72.59, 2.8]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, colors=colors,autopct='%.1f%%')
ax.set_aspect('equal')
plt.savefig('CFD.png', format='png', dpi=1000)
plt.show()
